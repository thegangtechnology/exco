# %% [markdown]
# # Make sure you change the kernel to excel_comment_orm

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from excel_comment_orm.example import add_number
add_number(2, 3)

# %% [markdown]
# ## Try uncomment subtract_number in src/excel_comment_orm/example.py

# %%
# from excel_comment_orm.example import subtract_number
# subtract_number(20,15)
